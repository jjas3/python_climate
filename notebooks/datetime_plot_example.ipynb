# %%
# %matplotlib inline
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import pylab as plt
import numpy as np
from mpl_toolkits.basemap import Basemap

# %%
import pandas as pd

# %%
print ('hello world')
# Out:
# hello world

# %%
import netCDF4 as nc

# %%
datafile = nc.Dataset('/scratch/ptg21/netscratch/omp27/f.e20.FCHIST.f09_f09_mg17.alpha07c_cam5_4_138.002.cam.h0.globavg.nc','r')

# %%
datafile.filepath()
# Out:
# u'/scratch/ptg21/netscratch/omp27/f.e20.FCHIST.f09_f09_mg17.alpha07c_cam5_4_138.002.cam.h0.globavg.nc'

# %%
lats = datafile.variables['lat'][:]
lons = datafile.variables['lon'][:]

# %%
AODUVstdn = datafile.variables['AODUVstdn']

# %%
print(AODUVstdn)
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float32 AODUVstdn(time)
#     _FillValue: 1e+36
#     missing_value: 1e+36
#     long_name: Stratospheric aerosol optical depth 350 nm, day night
#     cell_methods: time: mean lon: mean lat: mean
# unlimited dimensions: time
# current shape = (1980,)
# filling off

# %%
from datetime import datetime, timedelta
from netCDF4 import num2date, date2num
times1 = datafile.variables['time']
dates = num2date(times1[:],
                units=times1.units,
                calendar=times1.calendar)
a = pd.Series(AODUVstdn[:],index=dates)

# %%
today=datetime.now()

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)
a.plot(ax=ax,title='%s, plotted on %s' % (AODUVstdn.long_name,today))
ax.set_ylabel('AODUVstdn')

# %%
mean_o3 = np.mean(o3, axis=(0,1))

# %%
m3=Basemap(llcrnrlat=-90,urcrnrlat=90,llcrnrlon=0,urcrnrlon=360,resolution='c')
m3.drawcoastlines()
plt.contourf(lons, lats, mean_o3)
plt.colorbar()
