# %%
# %matplotlib inline

# %%
#from matplotlib import pyplot as plt
#import pandas as pd
import numpy as np
import netCDF4

# %%
from datetime import datetime, timedelta
from netCDF4 import num2date, date2num

# %%
data_root='/Users/ptg21/data/projects/UM_data'
filename     = data_root+'/xinyk/xinyka.pmk4.nc'
ncfile1      = netCDF4.Dataset(filename)
lon1         = ncfile1.variables['longitude'][:]
lat1         = ncfile1.variables['latitude'][:]
press1       = ncfile1.variables['p'][:]
hybrid_ht1   = ncfile1.variables['hybrid_ht'][:]
times1       = ncfile1.variables['t']
o3_1         = ncfile1.variables['field34001']

# %%
dates = num2date(times1[:],
                units=times1.units,
                calendar=times1.calendar)

# %%
print(np.shape(times1))
print(dates)
# Out:
# (12,)
# [datetime.datetime(2004, 1, 16, 12, 0)
#  datetime.datetime(2004, 2, 15, 12, 0)
#  datetime.datetime(2004, 3, 16, 12, 0) datetime.datetime(2004, 4, 16, 0, 0)
#  datetime.datetime(2004, 5, 16, 12, 0) datetime.datetime(2004, 6, 16, 0, 0)
#  datetime.datetime(2004, 7, 16, 12, 0)
#  datetime.datetime(2004, 8, 16, 12, 0) datetime.datetime(2004, 9, 16, 0, 0)
#  datetime.datetime(2004, 10, 16, 12, 0)
#  datetime.datetime(2004, 11, 16, 0, 0)
#  datetime.datetime(2004, 12, 16, 12, 0)]

# %%
filename     ='/Volumes/scratch/ptg21/UM_data/xlrua/xlruah9_k9_eval_output.nc'
ncfile1      = netCDF4.Dataset(filename)
lon1         = ncfile1.variables['longitude'][:]
lat1         = ncfile1.variables['latitude'][:]
hybrid_ht1   = ncfile1.variables['hybrid_ht'][:]
times1       = ncfile1.variables['time']
o3_1         = ncfile1.variables['mass_fraction_of_ozone_in_air']

# %%
dates = num2date(times1[:],
                units=times1.units,
                calendar=times1.calendar)

# %%
print(np.shape(times1))
print(dates)
# Out:
# (336,)
# [datetime.datetime(1979, 1, 16, 12, 0) datetime.datetime(1979, 2, 15, 0, 0)
#  datetime.datetime(1979, 3, 16, 12, 0) datetime.datetime(1979, 4, 16, 0, 0)
#  datetime.datetime(1979, 5, 16, 12, 0) datetime.datetime(1979, 6, 16, 0, 0)
#  datetime.datetime(1979, 7, 16, 12, 0)
#  datetime.datetime(1979, 8, 16, 12, 0) datetime.datetime(1979, 9, 16, 0, 0)
#  datetime.datetime(1979, 10, 16, 12, 0)
#  datetime.datetime(1979, 11, 16, 0, 0)
#  datetime.datetime(1979, 12, 16, 12, 0)
#  datetime.datetime(1980, 1, 16, 12, 0)
#  datetime.datetime(1980, 2, 15, 12, 0)
#  datetime.datetime(1980, 3, 16, 12, 0) datetime.datetime(1980, 4, 16, 0, 0)
#  datetime.datetime(1980, 5, 16, 12, 0) datetime.datetime(1980, 6, 16, 0, 0)
#  datetime.datetime(1980, 7, 16, 12, 0)
#  datetime.datetime(1980, 8, 16, 12, 0) datetime.datetime(1980, 9, 16, 0, 0)
#  datetime.datetime(1980, 10, 16, 12, 0)
#  datetime.datetime(1980, 11, 16, 0, 0)
#  datetime.datetime(1980, 12, 16, 12, 0)
# ...
